# %%
from preprocessing1 import PreProcessing

# %%
dataset = PreProcessing('./data_src', 'negative')
# Out:
# billmurray
# billnye
# obama
# Dataset loaded successfully.
# Preprocessing Done. Summary:
# Images train : (159, 368, 368, 3)
# Labels train : (159,)
# Images test  : (0,)
# Labels test  : (0,)
# Unique label : [0 1 2]

# %%
anchors = []
positives = []
negatives = []
n = 200
for _ in range(n):
    anchors.append(dataset.generate_triplets()[0])
    positives.append(dataset.generate_triplets()[1])
    negatives.append(dataset.generate_triplets()[2])
print((anchors[1].shape))
print((anchors[2].shape))
print((anchors[3].shape))
# Out:
# (368, 368, 3)
# (368, 368, 3)
# (368, 368, 3)

# %%
import numpy as np
def train_test_split(arr, p=.9):
    test = []
    train = []
    for i in range(len(arr)):
        if i < len(arr)*.9: train.append(arr[i])
        else: test.append(arr[i])
    return np.array(train), np.array(test)
#     return train, test

anchor_train, anchor_test = train_test_split(anchors)
print((anchor_train[1].shape))
print((anchor_train[3].shape))
positive_train, positive_test = train_test_split(positives)
negative_train, negative_test = train_test_split(negatives)
# Out:
# (368, 368, 3)
# (368, 368, 3)

# %%
def triplet_loss(y_true, y_pred, alpha = 0.4):
    """
    Implementation of the triplet loss function
    Arguments:
    y_true -- true labels, required when you define a loss in Keras, you don't need it in this function.
    y_pred -- python list containing three objects:
            anchor -- the encodings for the anchor data
            positive -- the encodings for the positive data (similar to anchor)
            negative -- the encodings for the negative data (different from anchor)
    Returns:
    loss -- real number, value of the loss
    """
    print('y_pred.shape = ',y_pred)
    
    total_lenght = y_pred.shape.as_list()[-1]
#     print('total_lenght=',  total_lenght)
#     total_lenght =12
    
    anchor = y_pred[:,0:int(total_lenght*1/3)]
    positive = y_pred[:,int(total_lenght*1/3):int(total_lenght*2/3)]
    negative = y_pred[:,int(total_lenght*2/3):int(total_lenght*3/3)]

    # distance between the anchor and the positive
    pos_dist = K.sum(K.square(anchor-positive),axis=1)

    # distance between the anchor and the negative
    neg_dist = K.sum(K.square(anchor-negative),axis=1)

    # compute loss
    basic_loss = pos_dist-neg_dist+alpha
    loss = K.maximum(basic_loss,0.0)
 
    return loss

# %%
from keras.layers import Input, Conv2D, Lambda, Dense, Flatten,MaxPooling2D, concatenate
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import os
from keras.callbacks import ModelCheckpoint
# os.environ['KMP_DUPLICATE_LIB_OK']='True'

def create_base_network(in_dims):
    """
    Base network to be shared.
    """
    model = Sequential()
    model.add(Conv2D(128,(7,7),padding='same',input_shape=(in_dims[0],in_dims[1],in_dims[2],),activation='relu',name='conv1'))
    model.add(MaxPooling2D((2,2),(2,2),padding='same',name='pool1'))
    model.add(Conv2D(256,(5,5),padding='same',activation='relu',name='conv2'))
    model.add(MaxPooling2D((2,2),(2,2),padding='same',name='pool2'))
    model.add(Flatten(name='flatten'))
    model.add(Dense(4,name='embeddings'))
    # model.add(Dense(600))
    
    return model

# %%
adam_optim = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999)

# %%
anchor_input = Input((368, 368, 3), name='anchor_input')
positive_input = Input((368, 368, 3), name='positive_input')
negative_input = Input((368, 368, 3), name='negative_input')

# Shared embedding layer for positive and negative items
Shared_DNN = create_base_network([368,368,3])


encoded_anchor = Shared_DNN(anchor_input)
encoded_positive = Shared_DNN(positive_input)
encoded_negative = Shared_DNN(negative_input)


merged_vector = concatenate([encoded_anchor, encoded_positive, encoded_negative], axis=-1, name='merged_layer')

model = Model(inputs=[anchor_input,positive_input, negative_input], outputs=merged_vector)
model.compile(loss=triplet_loss, optimizer=adam_optim)
# Out:
# y_pred.shape =  Tensor("merged_layer_1/concat:0", shape=(None, 12), dtype=float32)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# anchor_input (InputLayer)       (None, 368, 368, 3)  0
# __________________________________________________________________________________________________
# positive_input (InputLayer)     (None, 368, 368, 3)  0
# __________________________________________________________________________________________________
# negative_input (InputLayer)     (None, 368, 368, 3)  0
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 4)            9505540     anchor_input[0][0]
#                                                                  positive_input[0][0]
#                                                                  negative_input[0][0]
# ...

# %%
import numpy as np
Anchor_train = anchor_train.reshape(-1,368,368,3)
Positive_train = positive_train.reshape(-1,368,368,3)
Negative_train = negative_train.reshape(-1,368,368,3)
Anchor_test = anchor_test.reshape(-1,368,368,3)
Positive_test = positive_test.reshape(-1,368,368,3)
Negative_test = negative_test.reshape(-1,368,368,3)

# %%
import numpy as np

Y_dummy = np.empty((Anchor_train.shape[0],12))
Y_dummy2 = np.empty((Anchor_test.shape[0],12))

checkpointer = ModelCheckpoint(filepath="/tmp/weights.hdf5", verbose=1, save_best_only=True)
model.fit([Anchor_train,Positive_train,Negative_train],y=Y_dummy,validation_data=([Anchor_test,Positive_test,Negative_test],Y_dummy2),callbacks=[checkpointer], epochs=20)
# Out:
# Train on 180 samples, validate on 20 samples
# Epoch 1/20
# 180/180 [==============================] - 888s 5s/step - loss: 0.3995 - val_loss: 0.3931
#
# Epoch 00001: val_loss improved from inf to 0.39311, saving model to /tmp/weights.hdf5
# Epoch 2/20
# 180/180 [==============================] - 795s 4s/step - loss: 0.3943 - val_loss: 0.3902
#
# Epoch 00002: val_loss improved from 0.39311 to 0.39024, saving model to /tmp/weights.hdf5
# Epoch 3/20
# 180/180 [==============================] - 810s 5s/step - loss: 0.3867 - val_loss: 0.3787
#
# Epoch 00003: val_loss improved from 0.39024 to 0.37866, saving model to /tmp/weights.hdf5
# Epoch 4/20
# 180/180 [==============================] - 837s 5s/step - loss: 0.3595 - val_loss: 0.3634
#
# Epoch 00004: val_loss improved from 0.37866 to 0.36344, saving model to /tmp/weights.hdf5
# Epoch 5/20
# 180/180 [==============================] - 692s 4s/step - loss: 0.3554 - val_loss: 0.3580
#
# ...

# %%
trained_model = Model(inputs=anchor_input, outputs=encoded_anchor)

# %%
trained_model.load_weights('/tmp/weights.hdf5')

# %%
# x_train = anchor_train + positive_train + anchor_train
# x_test = anchor_test + positive_test + anchor_test

# %%
from sklearn.preprocessing import OneHotEncoder
X_train_trm = trained_model.predict(dataset.images_train.reshape(-1,368,368,3))
# X_test_trm = trained_model.predict(dataset.images_test.reshape(-1,368,368,3))

# %%
print(len(X_train_trm))
X_train_trm_new = X_train_trm[:100]
X_test_trm = X_train_trm[100:159]
print(len(X_train_trm_new))
print(len(X_test_trm))
# Out:
# 159
# 100
# 59

# %%
# y_train_onehot = enc.fit(dataset.labels_train)
# y_test_onehot = enc.fit(dataset.labels_test
#convert to onehot
y_train_onehot = np.zeros((dataset.labels_train.size, dataset.labels_train.max()+1))
y_train_onehot[np.arange(dataset.labels_train.size),dataset.labels_train] = 1

print(len(y_train_onehot))
y_train_onehot_new = y_train_onehot[:100]
y_test_onehot = y_train_onehot[100:159]

dataset.labels_test
# y_test_onehot = np.zeros((dataset.labels_test.size, dataset.labels_test.max()+1))
# y_test_onehot[np.arange(dataset.labels_test.size),dataset.labels_test] = 1
# dataset.labels_test.max()
print(len(y_test_onehot))
# Out:
# 159
# 59

# %%
Classifier_input = Input((4,))
Classifier_output = Dense(3, activation='softmax')(Classifier_input)
Classifier_model = Model(Classifier_input, Classifier_output)

Classifier_model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
print(len(X_train_trm_new))
print(len(y_train_onehot_new))
print(len(X_test_trm))
print(len(y_test_onehot))
# Out:
# 100
# 100
# 59
# 59

# %%
Classifier_model.fit(X_train_trm_new,y_train_onehot_new, validation_data=(X_test_trm,y_test_onehot),epochs=500)
# Out:
# Train on 100 samples, validate on 59 samples
# Epoch 1/500
# 100/100 [==============================] - 0s 3ms/step - loss: 1.1092 - accuracy: 0.3100 - val_loss: 1.0998 - val_accuracy: 0.3051
# Epoch 2/500
# 100/100 [==============================] - 0s 81us/step - loss: 1.1078 - accuracy: 0.3200 - val_loss: 1.0987 - val_accuracy: 0.3051
# Epoch 3/500
# 100/100 [==============================] - 0s 95us/step - loss: 1.1064 - accuracy: 0.3200 - val_loss: 1.0976 - val_accuracy: 0.3051
# Epoch 4/500
# 100/100 [==============================] - 0s 100us/step - loss: 1.1052 - accuracy: 0.3100 - val_loss: 1.0969 - val_accuracy: 0.2881
# Epoch 5/500
# 100/100 [==============================] - 0s 96us/step - loss: 1.1042 - accuracy: 0.3100 - val_loss: 1.0961 - val_accuracy: 0.3051
# Epoch 6/500
# 100/100 [==============================] - 0s 91us/step - loss: 1.1031 - accuracy: 0.3400 - val_loss: 1.0953 - val_accuracy: 0.3220
# Epoch 7/500
# ...
